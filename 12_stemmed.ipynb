# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnanigit/FMLLab/blob/main/12_stemmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import PorterStemmer
import nltk
nltk.download('punkt')
porter= PorterStemmer()
from nltk.tokenize import word_tokenize
def stemsent(text):
  text_words=word_tokenize(text)
  final=[]
  print(text_words)
  for i in text_words:
    final.append(porter.stem(i))
    final.append(" ")
  return "".join(final)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sentence="Pythoners are very intelligent and work very pythonly and now they are pythoning their way to success."
print("After stemming : ",stemsent(sentence))
# Out:
# ['Pythoners', 'are', 'very', 'intelligent', 'and', 'work', 'very', 'pythonly', 'and', 'now', 'they', 'are', 'pythoning', 'their', 'way', 'to', 'success', '.']
# After stemming :  python are veri intellig and work veri pythonli and now they are python their way to success .

# %%
#sigmoid

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(x):
  return 1/(1+np.exp(-x))
x=np.linspace(-10,10,50)
plt.plot(x,sigmoid(x))
plt.xlabel("x values")
plt.ylabel("sigmoid values")
plt.title("sigmoid activation function")
plt.show()
